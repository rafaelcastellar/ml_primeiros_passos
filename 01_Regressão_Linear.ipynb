# %% [markdown]
# # Regressão Linear
#
# Quando vemos uma relação em um diagrama de dispersão, podemos usar uma reta para resumir essa relação nos dados. Também podemos usar essa reta para fazer previsões a partir dos dados. Este processo é chamado de **regressão linear**.

# %% [markdown]
# ## Como ajustar uma reta aos dados
# Há maneiras mais avanças de ajustar uma reta aos dados, mas, em geral, queremos que a reta passe pelo "meio" dos pontos.
# ![texto do link](https://cdn.kastatic.org/ka-perseus-graphie/8bb165c7133f949876ebfa67d3419f8f3c4941a5.svg)
#
#
# ![](https://sigmoidal.ai/wp-content/uploads/2022/06/1w7xxhJu2HSnw8BGAhDukcw.gif)

# %% [markdown]
# ## Uso de equações para retas de regressão
# Depois de ajustarmos uma reta aos dados, encontramos sua equação e a usamos para fazer previsões.
#
# # *y = b + m.x*
#
# >**y** = valor do eixo y de determinado ponto da reta. É a nossa variável dependente.
# >
# >**b** = O coeficiente linear n da reta r é definido como o ponto onde a reta intercepta o eixo y, ou seja o ponto de coordenadas P(0,n).
# >
# >**m** = Podemos encontrar uma equação da reta r conhecendo a sua inclinação (direção), ou seja o valor do ângulo θ que a reta apresenta em relação ao eixo x.
# >
# >**x** = valor do eixo x de dertminado ponto da reta. No nosso caso, é a varíavel de entrada

# %% [markdown]
# **Exemplo: como encontrar a equação**
#
# A porcentagem de adultos fumantes, registrada de anos em anos desde
# 1967, indica uma relação linear negativa sem outliers. Uma reta foi ajustada aos dados para modelar a relação.
#
# ![texto do link](https://cdn.kastatic.org/ka-perseus-graphie/090ed95f56762c101205d1ee9435692267a9ec69.svg)

# %% [markdown]
# Fontes:
# https://pt.khanacademy.org/math/statistics-probability/describing-relationships-quantitative-data/introduction-to-trend-lines/a/linear-regression-review

# %% [markdown]
# # Pronto, você já sabe o que é **Regressão Linear**!
#
# ![](https://media.tenor.com/DwlsD4Xs__IAAAAd/looney-tunes-thats-all-folks.gif)

# %% [markdown]
# ## Bem fácil não é? Com duas variáveis sim?
#
# ## Mas e com 4, 13, 723 variáveis? 😨
#
# # **Regressão Linear Múltipla:**
#
#
# ## *Y = b0 + b1.x1 + b2.x2 + b3.x3 + …… bn.xn*
#
# ![](https://www.cranbournenorthdental.com.au/wp-content/uploads/2017/08/scared-Medium.jpg)

# %% [markdown]
# ---
#
# # **Bora por as mãos na massa!**

# %% [markdown]
# Montemos o Google drive pra acessar no dataset
# *(este passo só é necessário se você estiver rodando este notebook no Google Colab)*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **1. Importando e processando os dados**
#
# Nosso dataset contém registros oficiais de emissão de CO2 por vários carros, de diversos tipos e características, no Canadá. Há um total de 7385 linhas e 12 colunas. Os detalhes e significados podem ser obtidos aqui:
#
#  https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DataScience/data/CO2.csv')
df.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
# 6  ACURA          TL      MID-SIZE             3.5          6          AS6
# 7  ACURA      TL AWD      MID-SIZE             3.7          6          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7          6           M6
# 9  ACURA         TSX       COMPACT             2.4          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# ...

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %% [markdown]
# Temos que remover algumas colunas de caracteres que podem atrapalhar nosso modelo de regressão.

# %%
df.drop(['Make','Model','Vehicle Class','Transmission','Fuel Type'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# ...

# %% [markdown]
# ### **2. Encontrando Relacionamentos Lineares**
#
# Com as emissões de CO2 como a variável dependente, temos que encontrar algumas relações lineares positivas ou negativas implementando gráficos de dispersão. Essas variáveis ​​são posteriormente usadas para construir nossos modelos SLR e MLR. Para visualizações estatísticas, é melhor fazer uso da biblioteca marítima e então, vamos importá-la.

# %%
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize'] = (20,10)
# Out:
# <ipython-input-6-a47ef64eba29>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-whitegrid')

# %%
plt.figure(figsize=(10,8))
sb.pairplot(df)

# plt.savefig('pairplor.png')

# %% [markdown]
# Vamos representar graficamente qualquer variável independente única em relação à nossa variável dependente, que são as emissões de C02, para encontrar relações lineares entre elas
#
# **(i) Tamanho do motor / emissões de CO2:**

# %%
plt.figure(figsize=(6,6))
plt.scatter(x = 'Engine Size(L)', y = 'CO2 Emissions(g/km)', data = df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Engine size vs C02 Emissions')
plt.ylabel('CO2 Emissions')
plt.xlabel('Engine Size')

plt.savefig('enginesize_co2.png')

# %% [markdown]
# **(ii) Combustível Consumo Comb (L / 100 km) / Emissões de C02:**

# %%
plt.figure(figsize=(6,6))
plt.scatter(x = 'Fuel Consumption Comb (L/100 km)', y = 'CO2 Emissions(g/km)', data = df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Fuel Consumption Comb (L/100 km) vs C02 Emissions')
plt.ylabel('CO2 Emissions')
plt.xlabel('Fuel Consumption Comb (L/100 km)')

plt.savefig('fcc_co2')

# %% [markdown]
# **(iii) Consumo de combustível Hwy (L / 100 km) / emissões de CO2:**

# %%
plt.figure(figsize=(6,6))
plt.scatter(x = 'Fuel Consumption Hwy (L/100 km)', y = 'CO2 Emissions(g/km)', data = df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Fuel Consumption Hwy (L/100 km) vs C02 Emissions')
plt.ylabel('CO2 Emissions')
plt.xlabel('Fuel Consumption City (L/100 km)')

plt.savefig('fch_co2.png')

# %% [markdown]
# **(iv) Consumo de combustível na cidade (L / 100 km) / Emissões de CO2:**

# %%
plt.figure(figsize=(6,6))
plt.scatter(x = 'Fuel Consumption City (L/100 km)', y = 'CO2 Emissions(g/km)', data = df, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('Fuel Consumption City (L/100 km) vs C02 Emissions')
plt.ylabel('CO2 Emissions')
plt.xlabel('Fuel Consumption City (L/100 km)')

plt.savefig('fccity_co2.png')

# %% [markdown]
# Vejamos como as variáveis independentes se correlacionam entre si:

# %%
plt.figure(figsize=(10,6))
corr = df.corr()
sb.heatmap(corr, cmap="Greens", annot=True);
plt.title('Correlação entre as varíaveis')
# Out:
# Text(0.5, 1.0, 'Correlação entre as varíaveis')

# %% [markdown]
# ### **3. Modelo Regressão Linear Múltipla (MLR)**

# %% [markdown]
# Separando varíaveis independentes (X) da independente (y)

# %%
X1_var = df[['Engine Size(L)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption City (L/100 km)']]
y_var = df['CO2 Emissions(g/km)'] # dependent variable

# %% [markdown]
# Importando scikit-learn, separando dados de treinamento e teste

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X1_var, y_var, test_size = 0.3, random_state = 0)

# %% [markdown]
# Treinando modelo

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Realizando a predição

# %%
yhat = lr.predict(X_test)

yhat
# Out:
# array([239.94293701, 200.7681402 , 259.00872045, ..., 240.76102163,
#        213.52543311, 211.37958507])

# %% [markdown]
# Para verificar a precisão do modelo, podemos calcular a pontuação R-quadrada e podemos introduzir uma nova maneira que é por gráfico de distribuição.

# %%
print('R^2 Treino: ', lr.score(X_train, y_train))
print('R^2 Teste: ', lr.score(X_test, y_test))
# Out:
# R^2 Treino:  0.8770868223099806
# R^2 Teste:  0.8655946234480003

# %% [markdown]
# A seguir vemos o interecpto, que é o ponto de interceptação da reta no eixo Y, ou seja, quando x=0. É o *b0* da da nossa equação de regressão linear múltipla.

# %%
print('Intercepto:', lr.intercept_)
# Out:
# Intercepto: 61.81445738809563

# %% [markdown]
#  Vejamos como cada variável independente afeta a variável dependente:

# %%
coeff_df = pd.DataFrame(lr.coef_,X1_var.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                   Coefficient
# Engine Size(L)                      12.915913
# Fuel Consumption Comb (L/100 km)    11.674620
# Fuel Consumption Hwy (L/100 km)     -0.515682
# Fuel Consumption City (L/100 km)     1.946728

# %% [markdown]
# O segundo método para verificar a precisão do modelo MLR scikit-learn é construindo um gráfico de distribuição combinando os valores previstos e os valores reais.

# %%
plt.figure(figsize=(10,4))
sb.kdeplot(yhat,  color = 'r', label = 'Predicted Values')
sb.kdeplot(y_test, color = 'b', label = 'Actual Values')
plt.title('Actual vs Predicted Values')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend(loc = 'upper left',)

plt.savefig('ap.png')

# %% [markdown]
# Este gráfico de distribuição revela que nossos valores de previsão foram executados quase que precisamente em relação aos nossos valores reais, mas há alguns outliers que podem ser observados. Isso ocorre porque construímos um modelo muito básico de regressão linear para prever com precisão os resultados.

# %% [markdown]
# ### **4. Fazendo Predições**
#
# Vamos prever a emissão de combustível do meu carrão:

# %%
mavecão = pd.DataFrame({'Engine Size(L)':3, 'Fuel Consumption Comb (L/100 km)':20, 
       'Fuel Consumption Hwy (L/100 km)':14, 'Fuel Consumption City (L/100 km)':25}, index=[0])
minha_Pred = lr.predict(mavecão)
print('A emissão de CO2 do meu mavecão seria de {} g/km'\
      .format(round(minha_Pred[0], 2)))
# Out:
# A emissão de CO2 do meu mavecão seria de 375.5 g/km

# %%
uninho = pd.DataFrame({'Engine Size(L)':0.8, 'Fuel Consumption Comb (L/100 km)':5, 
       'Fuel Consumption Hwy (L/100 km)':5, 'Fuel Consumption City (L/100 km)':7}, index=[0])
minha_Pred = lr.predict(uninho)
print('A emissão de CO2 do meu uninho seria de {} g/km'\
      .format(round(minha_Pred[0], 2)))
# Out:
# A emissão de CO2 do meu uninho seria de 141.57 g/km

# %% [markdown]
# ---
#
#
#
# ---
#
#
# fontes:
#
# * https://ichi.pro/pt/guia-passo-a-passo-para-regressao-linear-simples-e-multipla-em-python-147861927035544
# * https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles
# * https://medium.com/@lamartine_sl/regress%C3%A3o-linear-com-sklearn-modelo-de-previs%C3%A3o-de-custos-com-plano-de-sa%C3%BAde-5e963e590f4c
# * https://datagy.io/python-sklearn-linear-regression/
